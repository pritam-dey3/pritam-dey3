# %%
from document import Document
from renderer import PyneconeMarkdown
from mistune import create_markdown
import black

markdown = create_markdown(renderer=PyneconeMarkdown())
doc = Document("sections/projects.md", markdown)
print(black.format_str(doc.body, mode=black.FileMode()))
# Out:
# ---------------------------------------------------------------------------
# InvalidInput                              Traceback (most recent call last)
# Cell In[2], line 7
#       4 import black
#       6 markdown = create_markdown(renderer=PyneconeMarkdown())
# ----> 7 doc = Document("sections/projects.md", markdown)
#       8 print(black.format_str(doc.body, mode=black.FileMode()))
#
# File /home/pritam/webapp/resume/resume/contents/document.py:15, in Document.__init__(self, path, markdown)
#      12 self.metadata: dict[str, str] = {}
#      13 self.markdown = markdown
# ---> 15 self.process()
#
# File /home/pritam/webapp/resume/resume/contents/document.py:40, in Document.process(self)
#      38 def process(self):
#      39     self.load()
# ---> 40     self.extract()
#
# File /home/pritam/webapp/resume/resume/contents/document.py:31, in Document.extract(self)
#      27     return
#      29 index = match.end()
# ---> 31 self.body = self.markdown(self.raw[index:])
# ...

# %%
from mistune.renderers.markdown import MarkdownRenderer
from mistune.core import BlockState
from typing import Any, Dict
import black


class TestPyneconeMarkdown(MarkdownRenderer):
    text_tmpl = "pc.text('''{raw}'''{props}), "
    block_tmpl = "pc.box({children}{props}), "
    paragraph_tmpl = "pc.vstack({children}{props}), "
    heading_tmpl = "pc.heading({children}{props}), "
    list_tmpl = "pc.list({children}{props}), "
    list_item_tmpl = "pc.list_item({children}{props}), "
    link_tmpl = "pc.link({children}{props}), "
    output_tmpl = "import pynecone as pc\ndef section()->pc.Component:\n\treturn pc.vstack({children}{props})"

    def __call__(self, tokens, state: BlockState):
        body = self.render_tokens(tokens, state)
        body = self.output_tmpl.format(children=body, props="")
        # return body
        return black.format_str(body, mode=black.FileMode())

    def text(self, token: dict[str, Any], state: BlockState) -> str:
        return self.text_tmpl.format(raw=token["raw"], props="")

    def block_text(self, token: dict[str, Any], state: BlockState) -> str:
        if "children" in token:
            if len(token["children"]) == 1:
                return self.render_children(token, state)
        return self.block_tmpl.format(
            children=self.render_children(token, state), props=""
        )

    def paragraph(self, token: Dict[str, Any], state: BlockState) -> str:
        if "children" in token:
            if len(token["children"]) == 1:
                return self.render_children(token, state)
        return self.paragraph_tmpl.format(
            children=self.render_children(token, state), props=""
        )

    def heading(self, token: Dict[str, Any], state: BlockState) -> str:
        level = token["attrs"]["level"]
        size = {1: "2xl", 2: "xl", 3: "lg", 4: "md", 5: "sm"}[level]
        return self.heading_tmpl.format(
            children=self.render_children(token, state), props=f"size='{size}'"
        )

    def list(self, token: Dict[str, Any], state: BlockState) -> str:
        ordered = token["attrs"]["ordered"]
        return self.list_tmpl.format(
            children=self.render_children(token, state), props=""
        )

    def list_item(self, token: Dict[str, Any], state: BlockState) -> str:
        return self.list_item_tmpl.format(
            children=self.render_children(token, state), props=""
        )

    def link(self, token: Dict[str, Any], state: BlockState) -> str:
        label = token.get("label")
        text = self.render_children(token, state)
        attrs = token["attrs"]
        url = attrs["url"]
        title = attrs.get("title")
        return self.link_tmpl.format(children=text, props=f"href='{url}', ")


markdown = create_markdown(renderer=TestPyneconeMarkdown())
doc = Document("sections/projects.md", markdown)
print(doc.body)
# Out:
# import pynecone as pc
#
#
# def section() -> pc.Component:
#     return pc.vstack(
#         pc.heading(pc.text("""Projects"""), size="xl"),
#         pc.heading(
#             pc.text(
#                 """Automatic team detection for any Bundesliga football match (March - April 2022)"""
#             ),
#             size="xl",
#         ),
#         pc.vstack(
#             pc.text(
#                 """Key points: Use YoloV7 for human, ball detection. Apply a sequence of classical computer vision + ML methods to detect specific jersey colors. I was able to overcome some critical challenges such as video feeds containing different lighting conditions (day / night), different colors of grass and jerseys of referees. """
#             ),
#             pc.link(
#                 pc.text("""GitHub"""),
#                 href="https://github.com/pritam-dey3/VisionDuo",
#             ),
#         ),
#         pc.heading(
#             pc.text(
# ...
